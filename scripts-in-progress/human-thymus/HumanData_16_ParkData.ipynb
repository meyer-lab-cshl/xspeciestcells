# %% [markdown]
# ## 1. Import

# %%
import scanpy as sc
import anndata
import pandas as pd

# %%
park_data = sc.read_h5ad("/Users/scarcy/Projects/HumanThymusProject/data/human-thymus/HumanData_16_ParkIntegration/HTA08_v01_A06_Science_human_tcells.h5ad")
print(park_data)
# Out:
# AnnData object with n_obs × n_vars = 76994 × 33694
#     obs: 'Sample', 'donor', 'organ', 'sort', 'method', 'file', 'is_TRA_p', 'is_TRB_p', 'is_TRA_np', 'is_TRB_np', 'Age', 'Source', 'cell types'
#     obsm: 'X_umap', 'X_umap_3d'
# /Users/scarcy/opt/anaconda3/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
park_data.obs
# Out:
#                                                     Sample donor organ sort  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT                 F21_TH_45P   F21    TH  45P
# FCAImmP7179369-AAACCTGAGCCTATGT                 F21_TH_45P   F21    TH  45P
# FCAImmP7179369-AAACCTGAGTCGCCGT                 F21_TH_45P   F21    TH  45P
# FCAImmP7179369-AAACCTGCAGCATGAG                 F21_TH_45P   F21    TH  45P
# FCAImmP7179369-AAACCTGGTCTCCCTA                 F21_TH_45P   F21    TH  45P
# ...                                                    ...   ...   ...  ...
# Human_colon_16S7985397-TTGTAGGCATACTCTT  F74_TH_TOT_5GEX_2   F74    TH  TOT
# Human_colon_16S7985397-TTGTAGGGTATAGTAG  F74_TH_TOT_5GEX_2   F74    TH  TOT
# Human_colon_16S7985397-TTTATGCGTCATGCCG  F74_TH_TOT_5GEX_2   F74    TH  TOT
# Human_colon_16S7985397-TTTGCGCAGAGCCCAA  F74_TH_TOT_5GEX_2   F74    TH  TOT
# Human_colon_16S7985397-TTTGGTTAGTACGCGA  F74_TH_TOT_5GEX_2   F74    TH  TOT
#
#                                         method                    file  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT           3GEX          FCAImmP7179369
# FCAImmP7179369-AAACCTGAGCCTATGT           3GEX          FCAImmP7179369
# FCAImmP7179369-AAACCTGAGTCGCCGT           3GEX          FCAImmP7179369
# FCAImmP7179369-AAACCTGCAGCATGAG           3GEX          FCAImmP7179369
# FCAImmP7179369-AAACCTGGTCTCCCTA           3GEX          FCAImmP7179369
# ...                                        ...                     ...
# Human_colon_16S7985397-TTGTAGGCATACTCTT   5GEX  Human_colon_16S7985397
# Human_colon_16S7985397-TTGTAGGGTATAGTAG   5GEX  Human_colon_16S7985397
# Human_colon_16S7985397-TTTATGCGTCATGCCG   5GEX  Human_colon_16S7985397
# Human_colon_16S7985397-TTTGCGCAGAGCCCAA   5GEX  Human_colon_16S7985397
# Human_colon_16S7985397-TTTGGTTAGTACGCGA   5GEX  Human_colon_16S7985397
#
#                                          is_TRA_p  is_TRB_p  is_TRA_np  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT             False     False      False
# FCAImmP7179369-AAACCTGAGCCTATGT             False     False      False
# FCAImmP7179369-AAACCTGAGTCGCCGT             False     False      False
# FCAImmP7179369-AAACCTGCAGCATGAG             False     False      False
# FCAImmP7179369-AAACCTGGTCTCCCTA             False     False      False
# ...                                           ...       ...        ...
# Human_colon_16S7985397-TTGTAGGCATACTCTT     False     False      False
# Human_colon_16S7985397-TTGTAGGGTATAGTAG     False     False      False
# Human_colon_16S7985397-TTTATGCGTCATGCCG     False     False      False
# Human_colon_16S7985397-TTTGCGCAGAGCCCAA     False     False      False
# Human_colon_16S7985397-TTTGGTTAGTACGCGA     False     False      False
#
#                                          is_TRB_np  Age Source  cell types
# index
# FCAImmP7179369-AAACCTGAGCCCAATT              False  16w   HDBR       CD8+T
# FCAImmP7179369-AAACCTGAGCCTATGT              False  16w   HDBR       CD4+T
# FCAImmP7179369-AAACCTGAGTCGCCGT              False  16w   HDBR       DP(P)
# FCAImmP7179369-AAACCTGCAGCATGAG              False  16w   HDBR       CD8+T
# FCAImmP7179369-AAACCTGGTCTCCCTA              False  16w   HDBR    CD8αα(I)
# ...                                            ...  ...    ...         ...
# Human_colon_16S7985397-TTGTAGGCATACTCTT      False  10w   HDBR  αβT(entry)
# Human_colon_16S7985397-TTGTAGGGTATAGTAG      False  10w   HDBR       DP(P)
# Human_colon_16S7985397-TTTATGCGTCATGCCG      False  10w   HDBR  αβT(entry)
# Human_colon_16S7985397-TTTGCGCAGAGCCCAA      False  10w   HDBR       DN(Q)
# Human_colon_16S7985397-TTTGGTTAGTACGCGA      False  10w   HDBR       DP(Q)
#
# [76994 rows x 13 columns]

# %%
park_data.X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a8bfe4f744bd> in <module>
# ----> 1 colnames(park_data.X)
#
# NameError: name 'colnames' is not defined

# %%
sc.pl.umap(park_data, color="cell types")

# %% [markdown]
# Following this forum suggestion: https://github.com/mojaveazure/seurat-disk/issues/7

# %%
#park_data = anndata.read("deprez19_restricted.processed.h5ad")
park_data.write("HTA08_v01_A06_Science_human_tcells.gzip.h5ad", compression="gzip")

# %% [markdown]
# Let's export the park metadata

# %%
park_metadata = pd.DataFrame(park_data.obs)
print(park_metadata)
park_metadata.to_csv("~/Projects/HumanThymusProject/data/human-thymus/HumanData_16_ParkIntegration/park_metadata.csv")
# Out:
#                                                     Sample donor organ sort  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT                 F21_TH_45P   F21    TH  45P
# FCAImmP7179369-AAACCTGAGCCTATGT                 F21_TH_45P   F21    TH  45P
# FCAImmP7179369-AAACCTGAGTCGCCGT                 F21_TH_45P   F21    TH  45P
# FCAImmP7179369-AAACCTGCAGCATGAG                 F21_TH_45P   F21    TH  45P
# FCAImmP7179369-AAACCTGGTCTCCCTA                 F21_TH_45P   F21    TH  45P
# ...                                                    ...   ...   ...  ...
# Human_colon_16S7985397-TTGTAGGCATACTCTT  F74_TH_TOT_5GEX_2   F74    TH  TOT
# Human_colon_16S7985397-TTGTAGGGTATAGTAG  F74_TH_TOT_5GEX_2   F74    TH  TOT
# Human_colon_16S7985397-TTTATGCGTCATGCCG  F74_TH_TOT_5GEX_2   F74    TH  TOT
# Human_colon_16S7985397-TTTGCGCAGAGCCCAA  F74_TH_TOT_5GEX_2   F74    TH  TOT
# Human_colon_16S7985397-TTTGGTTAGTACGCGA  F74_TH_TOT_5GEX_2   F74    TH  TOT
#
#                                         method                    file  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT           3GEX          FCAImmP7179369
# FCAImmP7179369-AAACCTGAGCCTATGT           3GEX          FCAImmP7179369
# FCAImmP7179369-AAACCTGAGTCGCCGT           3GEX          FCAImmP7179369
# FCAImmP7179369-AAACCTGCAGCATGAG           3GEX          FCAImmP7179369
# FCAImmP7179369-AAACCTGGTCTCCCTA           3GEX          FCAImmP7179369
# ...                                        ...                     ...
# Human_colon_16S7985397-TTGTAGGCATACTCTT   5GEX  Human_colon_16S7985397
# Human_colon_16S7985397-TTGTAGGGTATAGTAG   5GEX  Human_colon_16S7985397
# Human_colon_16S7985397-TTTATGCGTCATGCCG   5GEX  Human_colon_16S7985397
# Human_colon_16S7985397-TTTGCGCAGAGCCCAA   5GEX  Human_colon_16S7985397
# Human_colon_16S7985397-TTTGGTTAGTACGCGA   5GEX  Human_colon_16S7985397
#
#                                          is_TRA_p  is_TRB_p  is_TRA_np  \
# index
# FCAImmP7179369-AAACCTGAGCCCAATT             False     False      False
# FCAImmP7179369-AAACCTGAGCCTATGT             False     False      False
# FCAImmP7179369-AAACCTGAGTCGCCGT             False     False      False
# FCAImmP7179369-AAACCTGCAGCATGAG             False     False      False
# FCAImmP7179369-AAACCTGGTCTCCCTA             False     False      False
# ...                                           ...       ...        ...
# Human_colon_16S7985397-TTGTAGGCATACTCTT     False     False      False
# Human_colon_16S7985397-TTGTAGGGTATAGTAG     False     False      False
# Human_colon_16S7985397-TTTATGCGTCATGCCG     False     False      False
# Human_colon_16S7985397-TTTGCGCAGAGCCCAA     False     False      False
# Human_colon_16S7985397-TTTGGTTAGTACGCGA     False     False      False
#
#                                          is_TRB_np  Age Source  cell types
# index
# FCAImmP7179369-AAACCTGAGCCCAATT              False  16w   HDBR       CD8+T
# FCAImmP7179369-AAACCTGAGCCTATGT              False  16w   HDBR       CD4+T
# FCAImmP7179369-AAACCTGAGTCGCCGT              False  16w   HDBR       DP(P)
# FCAImmP7179369-AAACCTGCAGCATGAG              False  16w   HDBR       CD8+T
# FCAImmP7179369-AAACCTGGTCTCCCTA              False  16w   HDBR    CD8αα(I)
# ...                                            ...  ...    ...         ...
# Human_colon_16S7985397-TTGTAGGCATACTCTT      False  10w   HDBR  αβT(entry)
# Human_colon_16S7985397-TTGTAGGGTATAGTAG      False  10w   HDBR       DP(P)
# Human_colon_16S7985397-TTTATGCGTCATGCCG      False  10w   HDBR  αβT(entry)
# Human_colon_16S7985397-TTTGCGCAGAGCCCAA      False  10w   HDBR       DN(Q)
# Human_colon_16S7985397-TTTGGTTAGTACGCGA      False  10w   HDBR       DP(Q)
#
# [76994 rows x 13 columns]
